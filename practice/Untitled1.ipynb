# %%
from ollama import chat

stream = chat(
  model='qwen3-vl',
  messages=[{'role': 'user', 'content': 'What is 17 × 23?'}],
  stream=True,
)

in_thinking = False
content = ''
thinking = ''
for chunk in stream:
  if chunk.message.thinking:
    if not in_thinking:
      in_thinking = True
      print('Thinking:\n', end='', flush=True)
    print(chunk.message.thinking, end='', flush=True)
    # accumulate the partial thinking 
    thinking += chunk.message.thinking
  elif chunk.message.content:
    if in_thinking:
      in_thinking = False
      print('\n\nAnswer:\n', end='', flush=True)
    print(chunk.message.content, end='', flush=True)
    # accumulate the partial content
    content += chunk.message.content

  # append the accumulated fields to the messages for the next request
  new_messages = [{ 'role': 'assistant', 'thinking': thinking, 'content': content }]
# Out:
# Thinking:
# Okay, let's see. I need to calculate 17 multiplied by 23. Hmm, how do I do that? Maybe I can use the distributive property or break it down into easier parts. Let me think. 17 times 20 is one part, and 17 times 3 is another part. Yeah, that makes sense because 23 is 20 plus 3. So first, 17 times 20. Well, 17 times 2 is 34, so 17 times 20 is 340. Then 17 times 3 is 51. Then add those two results together: 340 plus 51. Let's check that. 340 plus 50 is 390, plus 1 more is 391. Wait, is that right? Let me verify another way. Maybe using the standard multiplication method. Write 17 on top and 23 below. Multiply 17 by 3 first: 3 times 7 is 21, write down 1 and carry over 2. Then 3 times 1 is 3, plus 2 is 5. So that's 51. Then multiply 17 by 2 (which is actually 20, so we need to shift one position to the left). 2 times 7 is 14, write down 4 and carry over 1. 2 times 1 is 2, plus 1 is 3. So that's 340, but shifted left, so it's 340. Then add 51 and 340. 340 + 51 is 391. Yeah, that matches. Let me check with another method, maybe the grid method. 17 is 10 + 7, 23 is 20 + 3. So (10 + 7)(20 + 3) = 10*20 + 10*3 + 7*20 + 7*3 = 200 + 30 + 140 + 21 = 200 + 30 is 230, plus 140 is 370, plus 21 is 391. Yep, same result. Maybe I can use a calculator to confirm, but since I'm supposed to do it manually, let's make sure. 17*23: 17*20=340, 17*3=51, 340+51=391. That's consistent across different methods. I think that's correct. Sometimes when multiplying, it's easy to mix up the numbers, but breaking it down into tens and ones helps. Let me try 23*17. 23*10=230, 23*7=161, then 230+161=391. Yep, same answer. So 17*23 is 391.
#
# Answer:
# To calculate $ 17 \times 23 $, we can break it down using the **distributive property** for easier computation.
#
# ---
#
# ### Step 1: Break Down the Numbers
#
# We know that:
#
# $$
# 23 = 20 + 3
# $$
#
# So,
#
# $$
# 17 \times 23 = 17 \times (20 + 3) = (17 \times 20) + (17 \times 3)
# $$
#
# ---
#
# ### Step 2: Compute Each Part
#
# - $ 17 \times 20 = 340 $
# - $ 17 \times 3 = 51 $
#
# ---
#
# ### Step 3: Add the Results
#
# $$
# 340 + 51 = 391
# $$
#
# ---
#
# ### Final Answer
#
# $$
# \boxed{391}
# $$
